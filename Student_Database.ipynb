# %%
import pymongo
import pandas as pd
import json
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6a03fba3-baf6-4303-9d19-33d198dfb298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a03fba3-baf6-4303-9d19-33d198dfb298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving students.json to students.json
# ...

# %%
df = pd.read_json("/content/students.json", lines = True)
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
type('/content/students.json')
# Out:
# str

# %%
abi = pymongo.MongoClient("mongodb://Abi123:abcdefgh@cluster0-shard-00-00.blxhr.mongodb.net:27017,cluster0-shard-00-01.blxhr.mongodb.net:27017,cluster0-shard-00-02.blxhr.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-1158iu-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
db = abi["assignment"]

# %%
dbs = db["Students"]

# %%
print(abi.list_database_names())
# Out:
# ['Abi', 'Assignment', 'client', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'tesla', 'admin', 'local']

# %%
db = abi["Assignment"]

# %%
print(db.list_collection_names())
# Out:
# ['students', 'Sum/Average']

# %%
col = db["students"]

# %%
sample = []
for i in col.find():
  sample.append(i)

# %%
sample
# Out:
# [{'_id': 0,
#   'name': 'aimee Zank',
#   'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#    {'score': 11.78273309957772, 'type': 'quiz'},
#    {'score': 35.8740349954354, 'type': 'homework'}]},
#  {'_id': 1,
#   'name': 'Aurelia Menendez',
#   'scores': [{'score': 60.06045071030959, 'type': 'exam'},
#    {'score': 52.79790691903873, 'type': 'quiz'},
#    {'score': 71.76133439165544, 'type': 'homework'}]},
#  {'_id': 2,
#   'name': 'Corliss Zuk',
#   'scores': [{'score': 67.03077096065002, 'type': 'exam'},
#    {'score': 6.301851677835235, 'type': 'quiz'},
#    {'score': 66.28344683278382, 'type': 'homework'}]},
#  {'_id': 3,
#   'name': 'Bao Ziglar',
#   'scores': [{'score': 71.64343899778332, 'type': 'exam'},
#    {'score': 24.80221293650313, 'type': 'quiz'},
#    {'score': 42.26147058804812, 'type': 'homework'}]},
#  {'_id': 4,
#   'name': 'Zachary Langlais',
#   'scores': [{'score': 78.68385091304332, 'type': 'exam'},
#    {'score': 90.2963101368042, 'type': 'quiz'},
# ...

# %%
df = pd.DataFrame(sample)

# %%
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
score_list = df["scores"].tolist()
score_list
# Out:
# [[{'score': 1.463179736705023, 'type': 'exam'},
#   {'score': 11.78273309957772, 'type': 'quiz'},
#   {'score': 35.8740349954354, 'type': 'homework'}],
#  [{'score': 60.06045071030959, 'type': 'exam'},
#   {'score': 52.79790691903873, 'type': 'quiz'},
#   {'score': 71.76133439165544, 'type': 'homework'}],
#  [{'score': 67.03077096065002, 'type': 'exam'},
#   {'score': 6.301851677835235, 'type': 'quiz'},
#   {'score': 66.28344683278382, 'type': 'homework'}],
#  [{'score': 71.64343899778332, 'type': 'exam'},
#   {'score': 24.80221293650313, 'type': 'quiz'},
#   {'score': 42.26147058804812, 'type': 'homework'}],
#  [{'score': 78.68385091304332, 'type': 'exam'},
#   {'score': 90.2963101368042, 'type': 'quiz'},
#   {'score': 34.41620148042529, 'type': 'homework'}],
#  [{'score': 44.87186330181261, 'type': 'exam'},
#   {'score': 25.72395114668016, 'type': 'quiz'},
#   {'score': 63.42288310628662, 'type': 'homework'}],
#  [{'score': 37.32285459166097, 'type': 'exam'},
# ...

# %%
score_list[0][0]
# Out:
# {'score': 1.463179736705023, 'type': 'exam'}

# %%
exam = []
for i in range(0,200):
  exam.append(score_list[i][0].get("score"))
exam
# Out:
# [1.463179736705023,
#  60.06045071030959,
#  67.03077096065002,
#  71.64343899778332,
#  78.68385091304332,
#  44.87186330181261,
#  37.32285459166097,
#  90.37826509157176,
#  22.13583712862635,
#  97.00509953654694,
#  45.61876862259409,
#  78.42617835651868,
#  54.29841278520669,
#  90.47179954427436,
#  25.15924151998215,
#  69.1565022533158,
#  7.772386442858281,
#  39.41011069729274,
#  62.12870233109035,
#  44.51211101958831,
#  42.17439799514388,
#  46.2289476258328,
#  75.04996547553947,
#  45.65432764125526,
#  86.0319702155683,
#  74.75289335591543,
#  19.17861192576963,
#  8.606983261043888,
#  3.677565278992456,
#  48.36644963899371,
#  15.89771199662455,
#  24.90138146001744,
#  87.14345376886205,
#  73.15861249943812,
#  7.112266875518214,
#  27.22049103148209,
#  73.055900093666,
#  86.06759716616264,
#  34.64373397163318,
#  0.04381116979284005,
#  84.53009035375172,
#  28.02518041693717,
#  44.62441703708117,
#  15.29147856258362,
#  98.06441387027331,
# ...

# %%
quiz = []
for i in range(0,200):
  quiz.append(score_list[i][1].get("score"))
quiz
# Out:
# [11.78273309957772,
#  52.79790691903873,
#  6.301851677835235,
#  24.80221293650313,
#  90.2963101368042,
#  25.72395114668016,
#  28.32634976913737,
#  42.48780666956811,
#  14.63969941335069,
#  97.80449632538915,
#  98.35723209418343,
#  82.58372817930675,
#  85.61270164694737,
#  90.3001402468489,
#  68.64484047692098,
#  3.311794422000724,
#  31.84300235104542,
#  81.13270307809924,
#  84.74586220889356,
#  0.6578497966368002,
#  71.99314840599558,
#  98.34164225207036,
#  10.23046475899236,
#  64.32927049658846,
#  1.967495200433389,
#  38.5413647805495,
#  76.3890359749654,
#  58.71180464203724,
#  7.119462599229987,
#  10.37827022865908,
#  56.93965183412178,
#  28.8266541837344,
#  99.45824441135635,
#  2.987718065941702,
#  67.734668378287,
#  31.28760039265919,
#  79.85621560462026,
#  79.45097452834857,
#  91.46799649446983,
#  90.25774974259562,
#  25.25568126160764,
#  95.25243105389065,
#  27.38208798553111,
#  78.40698797039501,
#  0.8760893342659504,
# ...

# %%
Homework = []
for i in range(0,200):
  Homework.append(score_list[i][2].get("score"))
Homework
# Out:
# [35.8740349954354,
#  71.76133439165544,
#  66.28344683278382,
#  42.26147058804812,
#  34.41620148042529,
#  63.42288310628662,
#  81.57115318686338,
#  96.52986171633331,
#  75.94123677556644,
#  25.27368532432955,
#  55.90835657173456,
#  87.49924733328717,
#  80.40732356118075,
#  95.17753772405909,
#  24.68462152686763,
#  45.03178973642521,
#  80.52136407989194,
#  97.70116640402922,
#  81.58947824932574,
#  93.36341655949683,
#  81.23972632069464,
#  36.18769746805938,
#  96.72520512117761,
#  83.53933351660562,
#  61.10861071547914,
#  35.2554340953413,
#  44.39605672647002,
#  15.33726210596508,
#  82.87308922617427,
#  93.26639335532833,
#  66.64493295066322,
#  97.16831550665721,
#  76.66460454219344,
#  82.54104198590488,
#  88.99855402666871,
#  79.23285425688643,
#  66.09143669040472,
#  28.41090281547689,
#  56.12615074082559,
#  65.88612319625227,
#  70.42062575402956,
#  68.05980405338909,
#  97.43587143437509,
#  31.03031764716336,
#  15.2177618920215,
# ...

# %%
len(exam)
# Out:
# 200

# %%
df["Quiz"] = quiz
df["Homework"] = Homework
df["Exam"] = exam

# %%
df
# Out:
#      _id              name                                             scores  \
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# ...

# %%
df = df.drop(['scores'], axis = 1)

# %%
df
# Out:
#      _id              name       Quiz   Homework       Exam
# 0      0        aimee Zank  11.782733  35.874035   1.463180
# 1      1  Aurelia Menendez  52.797907  71.761334  60.060451
# 2      2       Corliss Zuk   6.301852  66.283447  67.030771
# 3      3        Bao Ziglar  24.802213  42.261471  71.643439
# 4      4  Zachary Langlais  90.296310  34.416201  78.683851
# ..   ...               ...        ...        ...        ...
# 195  195     Linnie Weigel  90.777505  11.750084  52.445784
# 196  196  Santiago Dollins  33.633001  78.792574  52.040526
# 197  197     Tonisha Games  31.162876  79.158564  38.512696
# 198  198    Timothy Harrod  20.518800  64.856504  11.907567
# 199  199        Rae Kohout  49.612955  28.868237  82.117426
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#               _id        Quiz    Homework        Exam
# count  200.000000  200.000000  200.000000  200.000000
# mean    99.500000   48.996723   67.818696   48.673671
# std     57.879185   31.246695   22.465717   28.494072
# min      0.000000    0.006247   11.750084    0.043811
# 25%     49.750000   22.197422   54.397653   23.050956
# 50%     99.500000   45.362527   71.883264   45.941638
# 75%    149.250000   79.474781   87.144048   73.081578
# max    199.000000   99.803482   99.772377   99.336858

# %%
col_list= ['Quiz', 'Homework', 'Exam']
df['Total Score'] = df[col_list].sum(axis=1)

# %%
df
# Out:
#      _id              name       Quiz   Homework       Exam  Total_score  \
# 0      0        aimee Zank  11.782733  35.874035   1.463180    49.119948
# 1      1  Aurelia Menendez  52.797907  71.761334  60.060451   184.619692
# 2      2       Corliss Zuk   6.301852  66.283447  67.030771   139.616069
# 3      3        Bao Ziglar  24.802213  42.261471  71.643439   138.707123
# 4      4  Zachary Langlais  90.296310  34.416201  78.683851   203.396363
# ..   ...               ...        ...        ...        ...          ...
# 195  195     Linnie Weigel  90.777505  11.750084  52.445784   154.973373
# 196  196  Santiago Dollins  33.633001  78.792574  52.040526   164.466100
# 197  197     Tonisha Games  31.162876  79.158564  38.512696   148.834135
# 198  198    Timothy Harrod  20.518800  64.856504  11.907567    97.282871
# 199  199        Rae Kohout  49.612955  28.868237  82.117426   160.598617
#
#      Total Score
# 0      49.119948
# 1     184.619692
# 2     139.616069
# 3     138.707123
# ...

# %%
df[df["Total Score"]==df["Total Score"].max()]
# Out:
#     _id              name      Quiz   Homework     Exam  Total_score  \
# 13   13  Jessika Dagenais  90.30014  95.177538  90.4718   275.949478
#
#     Total Score
# 13   275.949478

# %%
df_pass = df[(df["Exam"]<(df["Exam"].mean()))&(df["Exam"]<40)]

# %%
df_pass
# Out:
#      _id              name       Quiz   Homework       Exam  Total_score  \
# 0      0        aimee Zank  11.782733  35.874035   1.463180    49.119948
# 6      6  Jenette Flanders  28.326350  81.571153  37.322855   147.220358
# 8      8      Daphne Zheng  14.639699  75.941237  22.135837   112.716773
# 14    14     Alix Sherrill  68.644840  24.684622  25.159242   118.488704
# 16    16     Dodie Staller  31.843002  80.521364   7.772386   120.136753
# ..   ...               ...        ...        ...        ...          ...
# 187  187    Devorah Smartt  13.273711  63.172811  23.946166   100.392688
# 192  192       Len Treiber  98.716793  44.822893  39.198329   182.738015
# 194  194      Echo Pippins  35.003070  80.179652  18.090137   133.272858
# 197  197     Tonisha Games  31.162876  79.158564  38.512696   148.834135
# 198  198    Timothy Harrod  20.518800  64.856504  11.907567    97.282871
#
#      Total Score
# 0      49.119948
# 6     147.220358
# 8     112.716773
# 14    118.488704
# ...

# %%
pass_mark = 0.4*300
pass_mark
# Out:
# 120.0

# %%
df["Status"] = np.where(df["Total Score"] > pass_mark,"Pass","Fail")

# %%
df
# Out:
#      _id              name       Quiz   Homework       Exam  Total_score  \
# 0      0        aimee Zank  11.782733  35.874035   1.463180    49.119948
# 1      1  Aurelia Menendez  52.797907  71.761334  60.060451   184.619692
# 2      2       Corliss Zuk   6.301852  66.283447  67.030771   139.616069
# 3      3        Bao Ziglar  24.802213  42.261471  71.643439   138.707123
# 4      4  Zachary Langlais  90.296310  34.416201  78.683851   203.396363
# ..   ...               ...        ...        ...        ...          ...
# 195  195     Linnie Weigel  90.777505  11.750084  52.445784   154.973373
# 196  196  Santiago Dollins  33.633001  78.792574  52.040526   164.466100
# 197  197     Tonisha Games  31.162876  79.158564  38.512696   148.834135
# 198  198    Timothy Harrod  20.518800  64.856504  11.907567    97.282871
# 199  199        Rae Kohout  49.612955  28.868237  82.117426   160.598617
#
#      Total Score Status
# 0      49.119948   Fail
# 1     184.619692   Pass
# ...

# %%
df.describe()
# Out:
#               _id        Quiz    Homework        Exam  Total_score  \
# count  200.000000  200.000000  200.000000  200.000000   200.000000
# mean    99.500000   48.996723   67.818696   48.673671   165.489090
# std     57.879185   31.246695   22.465717   28.494072    46.064352
# min      0.000000    0.006247   11.750084    0.043811    49.119948
# 25%     49.750000   22.197422   54.397653   23.050956   132.034336
# 50%     99.500000   45.362527   71.883264   45.941638   165.779500
# 75%    149.250000   79.474781   87.144048   73.081578   199.835087
# max    199.000000   99.803482   99.772377   99.336858   275.949478
#
#        Total Score
# count   200.000000
# mean    165.489090
# std      46.064352
# min      49.119948
# 25%     132.034336
# 50%     165.779500
# 75%     199.835087
# max     275.949478

# %%
df
# Out:
#      _id              name       Quiz   Homework       Exam  Total Score  \
# 0      0        aimee Zank  11.782733  35.874035   1.463180    49.119948
# 1      1  Aurelia Menendez  52.797907  71.761334  60.060451   184.619692
# 2      2       Corliss Zuk   6.301852  66.283447  67.030771   139.616069
# 3      3        Bao Ziglar  24.802213  42.261471  71.643439   138.707123
# 4      4  Zachary Langlais  90.296310  34.416201  78.683851   203.396363
# ..   ...               ...        ...        ...        ...          ...
# 195  195     Linnie Weigel  90.777505  11.750084  52.445784   154.973373
# 196  196  Santiago Dollins  33.633001  78.792574  52.040526   164.466100
# 197  197     Tonisha Games  31.162876  79.158564  38.512696   148.834135
# 198  198    Timothy Harrod  20.518800  64.856504  11.907567    97.282871
# 199  199        Rae Kohout  49.612955  28.868237  82.117426   160.598617
#
#     Status
# 0     Fail
# 1     Pass
# 2     Pass
# 3     Pass
# 4     Pass
# ..     ...
# ...

# %%
quiz_sum = df["Quiz"].sum()
quiz_sum
# Out:
# 9799.344638860508

# %%
homework_sum = df["Homework"].sum()
homework_sum
# Out:
# 13563.739241322295

# %%
exam_sum = df["Exam"].sum()
exam_sum
# Out:
# 9734.734151900351

# %%
quiz_mean = df["Quiz"].mean()
quiz_mean
# Out:
# 48.99672319430255

# %%
homework_mean = df["Homework"].mean()
homework_mean
# Out:
# 67.81869620661146

# %%
exam_mean = df["Exam"].mean()
exam_mean
# Out:
# 48.673670759501775

# %%
k = [{"Name":"Exam","Total":exam_sum,"Mean":exam_mean},{"Name":"Quiz","Total":quiz_sum,"Mean":quiz_mean},{"Name":"Homework","Total":homework_sum,"Mean":homework_mean}]

# %%
print(db.list_collection_names())
# Out:
# ['students', 'Sum/Average']

# %%
Four = db["Sum/Average"]

# %%
Four.insert_many(k)

# %%
print(db.list_collection_names())
# Out:
# ['students', 'Sum/Average']

# %%
Exam_average = df[(df["Exam"]<(df["Exam"].mean()))&(df["Exam"]>40)]

# %%
Homework_average = df[(df["Homework"]<(df["Homework"].mean()))&(df["Homework"]>40)]

# %%
Quiz_average = df[(df["Quiz"]<(df["Quiz"].mean()))&(df["Quiz"]>40)]

# %%
df = df.drop(['Total_score'], axis = 1)

# %%
print(db.list_collection_names())
# Out:
# ['students', 'Sum/Average']

# %%
Five = db["Abovepassbelowaverage"]

# %%
c = [{"Name":"Exam","Data":Exam_average},{"Name":"Quiz","Data":Quiz_average},{"Name":"Homework","Data":Homework_average}]

# %%
df["Total Score"].mean()
# Out:
# 165.48909016041569

# %%
Totalscore_average = df[(df["Total Score"]<df["Total Score"].mean())&(df["Total Score"]>120)]

# %%
type(Totalscore_average)
# Out:
# pandas.core.frame.DataFrame

# %%
c = Totalscore_average.to_dict('records')

# %%
Five.insert_many(c)

# %%
Failed_students = df[(df["Total Score"]<120)]
Failed_students
# Out:
#      _id                 name       Quiz   Homework       Exam  Total Score  \
# 0      0           aimee Zank  11.782733  35.874035   1.463180    49.119948
# 8      8         Daphne Zheng  14.639699  75.941237  22.135837   112.716773
# 14    14        Alix Sherrill  68.644840  24.684622  25.159242   118.488704
# 15    15       Tambra Mercure   3.311794  45.031790  69.156502   117.500086
# 27    27         Edgar Sarkis  58.711805  15.337262   8.606983    82.656050
# 28    28     Laureen Salomone   7.119463  82.873089   3.677565    93.670117
# 44    44      Houston Valenti   0.876089  15.217762  98.064414   114.158265
# 45    45       Terica Brugger  41.736541  18.912872  42.101131   102.750545
# 56    56      Danika Loeffler  41.759621  55.701955  21.545317   119.006893
# 63    63         Rubie Winton  46.324269  19.243128   7.176062    72.743459
# 66    66               Kim Xu  17.529662  57.329831  19.965318    94.824811
# ...

# %%
F = Failed_students.to_dict('record')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
Six = db["Failstudents"]

# %%
Six.insert_many(F)

# %%
Seven = db["Passstudents"]

# %%
Pass_students = df[(df["Total Score"]>120)]
Pass_students
# Out:
#      _id              name       Quiz   Homework       Exam  Total Score  \
# 1      1  Aurelia Menendez  52.797907  71.761334  60.060451   184.619692
# 2      2       Corliss Zuk   6.301852  66.283447  67.030771   139.616069
# 3      3        Bao Ziglar  24.802213  42.261471  71.643439   138.707123
# 4      4  Zachary Langlais  90.296310  34.416201  78.683851   203.396363
# 5      5    Wilburn Spiess  25.723951  63.422883  44.871863   134.018698
# ..   ...               ...        ...        ...        ...          ...
# 194  194      Echo Pippins  35.003070  80.179652  18.090137   133.272858
# 195  195     Linnie Weigel  90.777505  11.750084  52.445784   154.973373
# 196  196  Santiago Dollins  33.633001  78.792574  52.040526   164.466100
# 197  197     Tonisha Games  31.162876  79.158564  38.512696   148.834135
# 199  199        Rae Kohout  49.612955  28.868237  82.117426   160.598617
#
#     Status
# 1     Pass
# 2     Pass
# 3     Pass
# 4     Pass
# 5     Pass
# ..     ...
# ...

# %%
P = Pass_students.to_dict('rec')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
Seven.insert_many(P)
